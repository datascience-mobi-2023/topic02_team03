# %% [markdown]
# This notebook shows the two histograms from our project proposal.

# %% [markdown]
# First, the histogramm showing the distribution of data over the different mutation counts.

# %%
import pandas as pd
import seaborn as sns
import numpy as np

original_dms_data = pd.read_csv("/Users/liza/Documents/Bioinfo Project/DMS_data/AAAA_GFP_dms_data_original_komplett.csv")
# alle Daten einlesen, komplette Tabelle
only_smal_dms_dat = original_dms_data['mutant']
# nur die Spalte mit den Definitionen der Mutanten
import seaborn as sns
import matplotlib.pyplot as plt


ax = sns.histplot(data=list_mut_count + 1, discrete=True)

ax.set_facecolor('white')
ax.spines['bottom'].set_color('black')
#ax.spines['top'].set_color('black')
ax.spines['left'].set_color('black')
#ax.spines['right'].set_color('black')


for patch in ax.patches:
    patch.set_facecolor('blue')

plt.savefig('FS x mutation count histogram.png', dpi=300, bbox_inches='tight', facecolor=ax.get_facecolor())

plt.show()

# %% [markdown]
# Generating a histogram showing the distribution of fitness scores thorughout the whole dataset

# %%
ax = sns.histplot(data=original_dms_data, x="DMS_score")
ax.set_facecolor('white')
for patch in ax.patches:
    patch.set_facecolor('blue')
    # Set the color of the axes to black
ax.spines['bottom'].set_color('black')
#ax.spines['top'].set_color('black')
ax.spines['left'].set_color('black')
#ax.spines['right'].set_color('black')

plt.savefig('FS x count histogram.png', dpi=300, bbox_inches='tight', facecolor=ax.get_facecolor())

plt.show()
